# %%
import pandas as pd
import matplotlib.pyplot as plt

train = pd.read_csv('../data/processed/train.csv')

plt.scatter(train['gene_1'], train['gene_2'])
plt.title('Scatter Plot of Gene 1 vs Gene 2')
plt.xlabel('Gene 1')
plt.ylabel('Gene 2')
plt.show()
